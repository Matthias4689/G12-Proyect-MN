# %%
# Librerías
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# Función que muestra la trayectoria del proyectil
def dibujo(coordX, coordY):
  plt.figure(figsize=(10,5))
  plt.plot(coordX, coordY, label="Trayectoria de la jabalina")
  plt.title("Simulación de la Trayectoria de la jabalina")
  plt.xlabel("Distancia horizontal (m)")
  plt.ylabel("Altura (m)")
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
def simulacion(theta):
  # Parámetros modificables
  V = 43.25        # Velocidad inicial en m/s

  # Parametros jabalina
  m = 0.8         # Masa de la jabalina en kg
  A = 0.007       # Área transversal en m²

  # Parametros fisicos
  Cd = 0.04       # Coeficiente de arrastre
  rho = 1.225     # Densidad del aire en kg/m³
  g = 9.81        # Aceleración debida a la gravedad en m/s²

  # Tamaño del paso de tiempo en segundos
  h = 0.01

  # Condiciones iniciales
  # Coordenadas iniciales en metros
  x = 0.0 # En X
  y = 0.0 # En X

  # Tiempo inicial en segundos
  t = 0.0

  # Componentes de velocidad
  Vx = V * np.cos(theta)  # En X
  Vy = V * np.sin(theta)  # En Y

  # Listas para almacenar los resultados
  x_vals = [x]
  y_vals = [y]

  # Método de Runge-Kutta de cuarto orden
  while y >= 0:
    # Calcular k1 (Orden 1)
    k1x = h * (Vx - (0.5 * Cd * A * rho * Vx * np.abs(Vx)) / m)
    k1y = h * (Vy - g - (0.5 * Cd * A * rho * Vy * np.abs(Vy)) / m)

    # Calcular k2 (Orden 2)
    k2x = h * (Vx + 0.5 * k1x - g - (0.5 * Cd * A * rho * (Vx + 0.5 * k1x) * np.abs(Vx + 0.5 * k1x)) / m)
    k2y = h * (Vy + 0.5 * k1y - g - (0.5 * Cd * A * rho * (Vy + 0.5 * k1y) * np.abs(Vy + 0.5 * k1y)) / m)

    # Calcular k3 (Orden 3)
    k3x = h * (Vx + 0.5 * k2x - (0.5 * Cd * A * rho * (Vx + 0.5 * k2x) * np.abs(Vx + 0.5 * k2x)) / m)
    k3y = h * (Vy + 0.5 * k2y - g - (0.5 * Cd * A * rho * (Vy + 0.5 * k2y) * np.abs(Vy + 0.5 * k2y)) / m)

    # Calcular k4 (Orden 4)
    k4x = h * (Vx + k3x - (0.5 * Cd * A * rho * (Vx + k3x) * np.abs(Vx + k3x)) / m)
    k4y = h * (Vy + k3y - g - (0.5 * Cd * A * rho * (Vy + k3y) * np.abs(Vy + k3y)) / m)

    # Actualización de variables
    x = x + (k1x + 2 * k2x + 2 * k3x + k4x) / 6
    y = y + (k1y + 2 * k2y + 2 * k3y + k4y) / 6

    t = t + h

    Vx = Vx - (0.5 * Cd * A * rho * Vx * np.abs(Vx) * h) / m
    Vy = Vy - g * h - (0.5 * Cd * A * rho * Vy * np.abs(Vy) * h) / m

    # Almacenar los resultados
    x_vals.append(x)
    y_vals.append(y)

  return x_vals

# %%
x = 0

for grados in range(0, 91):

    radianes = grados * (math.pi / 180)

    xR = simulacion(radianes)

    xAux = max(xR)

    if(xAux >= x):

      x = xAux
      angulo = radianes * (180 / math.pi)

print(x," ",angulo)
# Out:
# 114.00382690821257   48.00000000000001

# %%
# Parámetros modificables
theta = 0.785398  # Ángulo de elevación en radianes
V = 40.91     # Velocidad inicial en m/s
# Parametros jabalina
m = 0.8         # Masa de la jabalina en kg
A = 0.007       # Área transversal en m²

# Parametros fisicos
Cd = 0.04       # Coeficiente de arrastre
rho = 1.225     # Densidad del aire en kg/m³
g = 9.81        # Aceleración debida a la gravedad en m/s²

# Tamaño del paso de tiempo en segundos
h = 0.01

# Condiciones iniciales
# Coordenadas iniciales en metros
x = 0.0 # En X
y = 0.0 # En X

# Tiempo inicial en segundos
t = 0.0

# Componentes de velocidad
Vx = V * np.cos(theta)  # En X
Vy = V * np.sin(theta)  # En Y

# Listas para almacenar los resultados
x_vals = [x]
y_vals = [y]

# Método de Runge-Kutta de cuarto orden
while y >= 0:
    # Calcular k1 (Orden 1)
    k1x = h * (Vx - (0.5 * Cd * A * rho * Vx * np.abs(Vx)) / m)
    k1y = h * (Vy - g - (0.5 * Cd * A * rho * Vy * np.abs(Vy)) / m)

    # Calcular k2 (Orden 2)
    k2x = h * (Vx + 0.5 * k1x - g - (0.5 * Cd * A * rho * (Vx + 0.5 * k1x) * np.abs(Vx + 0.5 * k1x)) / m)
    k2y = h * (Vy + 0.5 * k1y - g - (0.5 * Cd * A * rho * (Vy + 0.5 * k1y) * np.abs(Vy + 0.5 * k1y)) / m)

    # Calcular k3 (Orden 3)
    k3x = h * (Vx + 0.5 * k2x - (0.5 * Cd * A * rho * (Vx + 0.5 * k2x) * np.abs(Vx + 0.5 * k2x)) / m)
    k3y = h * (Vy + 0.5 * k2y - g - (0.5 * Cd * A * rho * (Vy + 0.5 * k2y) * np.abs(Vy + 0.5 * k2y)) / m)

    # Calcular k4 (Orden 4)
    k4x = h * (Vx + k3x - (0.5 * Cd * A * rho * (Vx + k3x) * np.abs(Vx + k3x)) / m)
    k4y = h * (Vy + k3y - g - (0.5 * Cd * A * rho * (Vy + k3y) * np.abs(Vy + k3y)) / m)

    # Actualización de variables
    x = x + (k1x + 2 * k2x + 2 * k3x + k4x) / 6
    y = y + (k1y + 2 * k2y + 2 * k3y + k4y) / 6

    t = t + h

    Vx = Vx - (0.5 * Cd * A * rho * Vx * np.abs(Vx) * h) / m
    Vy = Vy - g * h - (0.5 * Cd * A * rho * Vy * np.abs(Vy) * h) / m

    # Almacenar los resultados
    x_vals.append(x)
    y_vals.append(y)

# Imprimir resultados
for i in range(len(x_vals)):
    print(f"Tiempo: {i*h:.2f} s - Posición (x, y): ({x_vals[i]:.2f} m, {y_vals[i]:.2f} m)")

# Imprime la gráfica con la trayectoria
dibujo(x_vals ,y_vals)
# Out:
# Tiempo: 0.00 s - Posición (x, y): (0.00 m, 0.00 m)
# Tiempo: 0.01 s - Posición (x, y): (0.26 m, 0.19 m)
# Tiempo: 0.02 s - Posición (x, y): (0.51 m, 0.38 m)
# Tiempo: 0.03 s - Posición (x, y): (0.77 m, 0.57 m)
# Tiempo: 0.04 s - Posición (x, y): (1.02 m, 0.76 m)
# Tiempo: 0.05 s - Posición (x, y): (1.28 m, 0.94 m)
# Tiempo: 0.06 s - Posición (x, y): (1.54 m, 1.13 m)
# Tiempo: 0.07 s - Posición (x, y): (1.79 m, 1.31 m)
# Tiempo: 0.08 s - Posición (x, y): (2.05 m, 1.49 m)
# Tiempo: 0.09 s - Posición (x, y): (2.30 m, 1.68 m)
# Tiempo: 0.10 s - Posición (x, y): (2.56 m, 1.86 m)
# Tiempo: 0.11 s - Posición (x, y): (2.82 m, 2.04 m)
# Tiempo: 0.12 s - Posición (x, y): (3.07 m, 2.22 m)
# Tiempo: 0.13 s - Posición (x, y): (3.33 m, 2.40 m)
# Tiempo: 0.14 s - Posición (x, y): (3.58 m, 2.57 m)
# Tiempo: 0.15 s - Posición (x, y): (3.84 m, 2.75 m)
# Tiempo: 0.16 s - Posición (x, y): (4.09 m, 2.93 m)
# Tiempo: 0.17 s - Posición (x, y): (4.35 m, 3.10 m)
# Tiempo: 0.18 s - Posición (x, y): (4.61 m, 3.27 m)
# Tiempo: 0.19 s - Posición (x, y): (4.86 m, 3.45 m)
# Tiempo: 0.20 s - Posición (x, y): (5.12 m, 3.62 m)
# Tiempo: 0.21 s - Posición (x, y): (5.37 m, 3.79 m)
# Tiempo: 0.22 s - Posición (x, y): (5.63 m, 3.96 m)
# Tiempo: 0.23 s - Posición (x, y): (5.88 m, 4.13 m)
# Tiempo: 0.24 s - Posición (x, y): (6.14 m, 4.29 m)
# Tiempo: 0.25 s - Posición (x, y): (6.40 m, 4.46 m)
# Tiempo: 0.26 s - Posición (x, y): (6.65 m, 4.63 m)
# Tiempo: 0.27 s - Posición (x, y): (6.91 m, 4.79 m)
# Tiempo: 0.28 s - Posición (x, y): (7.16 m, 4.95 m)
# Tiempo: 0.29 s - Posición (x, y): (7.42 m, 5.12 m)
# Tiempo: 0.30 s - Posición (x, y): (7.67 m, 5.28 m)
# Tiempo: 0.31 s - Posición (x, y): (7.93 m, 5.44 m)
# Tiempo: 0.32 s - Posición (x, y): (8.18 m, 5.60 m)
# Tiempo: 0.33 s - Posición (x, y): (8.44 m, 5.76 m)
# Tiempo: 0.34 s - Posición (x, y): (8.70 m, 5.92 m)
# Tiempo: 0.35 s - Posición (x, y): (8.95 m, 6.07 m)
# Tiempo: 0.36 s - Posición (x, y): (9.21 m, 6.23 m)
# Tiempo: 0.37 s - Posición (x, y): (9.46 m, 6.38 m)
# Tiempo: 0.38 s - Posición (x, y): (9.72 m, 6.54 m)
# Tiempo: 0.39 s - Posición (x, y): (9.97 m, 6.69 m)
# Tiempo: 0.40 s - Posición (x, y): (10.23 m, 6.84 m)
# Tiempo: 0.41 s - Posición (x, y): (10.48 m, 6.99 m)
# Tiempo: 0.42 s - Posición (x, y): (10.74 m, 7.14 m)
# Tiempo: 0.43 s - Posición (x, y): (10.99 m, 7.29 m)
# Tiempo: 0.44 s - Posición (x, y): (11.25 m, 7.44 m)
# Tiempo: 0.45 s - Posición (x, y): (11.50 m, 7.58 m)
# Tiempo: 0.46 s - Posición (x, y): (11.76 m, 7.73 m)
# Tiempo: 0.47 s - Posición (x, y): (12.01 m, 7.87 m)
# Tiempo: 0.48 s - Posición (x, y): (12.27 m, 8.02 m)
# Tiempo: 0.49 s - Posición (x, y): (12.53 m, 8.16 m)
# Tiempo: 0.50 s - Posición (x, y): (12.78 m, 8.30 m)
# Tiempo: 0.51 s - Posición (x, y): (13.04 m, 8.44 m)
# Tiempo: 0.52 s - Posición (x, y): (13.29 m, 8.58 m)
# Tiempo: 0.53 s - Posición (x, y): (13.55 m, 8.72 m)
# Tiempo: 0.54 s - Posición (x, y): (13.80 m, 8.86 m)
# Tiempo: 0.55 s - Posición (x, y): (14.06 m, 9.00 m)
# Tiempo: 0.56 s - Posición (x, y): (14.31 m, 9.13 m)
# Tiempo: 0.57 s - Posición (x, y): (14.57 m, 9.27 m)
# Tiempo: 0.58 s - Posición (x, y): (14.82 m, 9.40 m)
# Tiempo: 0.59 s - Posición (x, y): (15.08 m, 9.54 m)
# Tiempo: 0.60 s - Posición (x, y): (15.33 m, 9.67 m)
# Tiempo: 0.61 s - Posición (x, y): (15.59 m, 9.80 m)
# Tiempo: 0.62 s - Posición (x, y): (15.84 m, 9.93 m)
# Tiempo: 0.63 s - Posición (x, y): (16.10 m, 10.06 m)
# Tiempo: 0.64 s - Posición (x, y): (16.35 m, 10.18 m)
# Tiempo: 0.65 s - Posición (x, y): (16.61 m, 10.31 m)
# Tiempo: 0.66 s - Posición (x, y): (16.86 m, 10.44 m)
# Tiempo: 0.67 s - Posición (x, y): (17.12 m, 10.56 m)
# Tiempo: 0.68 s - Posición (x, y): (17.37 m, 10.69 m)
# Tiempo: 0.69 s - Posición (x, y): (17.63 m, 10.81 m)
# Tiempo: 0.70 s - Posición (x, y): (17.88 m, 10.93 m)
# Tiempo: 0.71 s - Posición (x, y): (18.14 m, 11.05 m)
# Tiempo: 0.72 s - Posición (x, y): (18.39 m, 11.17 m)
# Tiempo: 0.73 s - Posición (x, y): (18.64 m, 11.29 m)
# Tiempo: 0.74 s - Posición (x, y): (18.90 m, 11.41 m)
# Tiempo: 0.75 s - Posición (x, y): (19.15 m, 11.53 m)
# Tiempo: 0.76 s - Posición (x, y): (19.41 m, 11.64 m)
# Tiempo: 0.77 s - Posición (x, y): (19.66 m, 11.76 m)
# Tiempo: 0.78 s - Posición (x, y): (19.92 m, 11.87 m)
# Tiempo: 0.79 s - Posición (x, y): (20.17 m, 11.99 m)
# Tiempo: 0.80 s - Posición (x, y): (20.43 m, 12.10 m)
# Tiempo: 0.81 s - Posición (x, y): (20.68 m, 12.21 m)
# Tiempo: 0.82 s - Posición (x, y): (20.94 m, 12.32 m)
# Tiempo: 0.83 s - Posición (x, y): (21.19 m, 12.43 m)
# Tiempo: 0.84 s - Posición (x, y): (21.45 m, 12.54 m)
# Tiempo: 0.85 s - Posición (x, y): (21.70 m, 12.64 m)
# Tiempo: 0.86 s - Posición (x, y): (21.96 m, 12.75 m)
# Tiempo: 0.87 s - Posición (x, y): (22.21 m, 12.86 m)
# Tiempo: 0.88 s - Posición (x, y): (22.46 m, 12.96 m)
# Tiempo: 0.89 s - Posición (x, y): (22.72 m, 13.06 m)
# Tiempo: 0.90 s - Posición (x, y): (22.97 m, 13.17 m)
# Tiempo: 0.91 s - Posición (x, y): (23.23 m, 13.27 m)
# Tiempo: 0.92 s - Posición (x, y): (23.48 m, 13.37 m)
# Tiempo: 0.93 s - Posición (x, y): (23.74 m, 13.47 m)
# Tiempo: 0.94 s - Posición (x, y): (23.99 m, 13.57 m)
# Tiempo: 0.95 s - Posición (x, y): (24.25 m, 13.66 m)
# Tiempo: 0.96 s - Posición (x, y): (24.50 m, 13.76 m)
# Tiempo: 0.97 s - Posición (x, y): (24.75 m, 13.86 m)
# Tiempo: 0.98 s - Posición (x, y): (25.01 m, 13.95 m)
# Tiempo: 0.99 s - Posición (x, y): (25.26 m, 14.04 m)
# Tiempo: 1.00 s - Posición (x, y): (25.52 m, 14.14 m)
# Tiempo: 1.01 s - Posición (x, y): (25.77 m, 14.23 m)
# Tiempo: 1.02 s - Posición (x, y): (26.03 m, 14.32 m)
# Tiempo: 1.03 s - Posición (x, y): (26.28 m, 14.41 m)
# Tiempo: 1.04 s - Posición (x, y): (26.53 m, 14.50 m)
# Tiempo: 1.05 s - Posición (x, y): (26.79 m, 14.58 m)
# Tiempo: 1.06 s - Posición (x, y): (27.04 m, 14.67 m)
# Tiempo: 1.07 s - Posición (x, y): (27.30 m, 14.76 m)
# Tiempo: 1.08 s - Posición (x, y): (27.55 m, 14.84 m)
# Tiempo: 1.09 s - Posición (x, y): (27.80 m, 14.92 m)
# Tiempo: 1.10 s - Posición (x, y): (28.06 m, 15.01 m)
# Tiempo: 1.11 s - Posición (x, y): (28.31 m, 15.09 m)
# Tiempo: 1.12 s - Posición (x, y): (28.57 m, 15.17 m)
# Tiempo: 1.13 s - Posición (x, y): (28.82 m, 15.25 m)
# Tiempo: 1.14 s - Posición (x, y): (29.08 m, 15.33 m)
# Tiempo: 1.15 s - Posición (x, y): (29.33 m, 15.40 m)
# Tiempo: 1.16 s - Posición (x, y): (29.58 m, 15.48 m)
# Tiempo: 1.17 s - Posición (x, y): (29.84 m, 15.56 m)
# Tiempo: 1.18 s - Posición (x, y): (30.09 m, 15.63 m)
# Tiempo: 1.19 s - Posición (x, y): (30.35 m, 15.71 m)
# Tiempo: 1.20 s - Posición (x, y): (30.60 m, 15.78 m)
# Tiempo: 1.21 s - Posición (x, y): (30.85 m, 15.85 m)
# Tiempo: 1.22 s - Posición (x, y): (31.11 m, 15.92 m)
# Tiempo: 1.23 s - Posición (x, y): (31.36 m, 15.99 m)
# Tiempo: 1.24 s - Posición (x, y): (31.61 m, 16.06 m)
# Tiempo: 1.25 s - Posición (x, y): (31.87 m, 16.13 m)
# Tiempo: 1.26 s - Posición (x, y): (32.12 m, 16.19 m)
# Tiempo: 1.27 s - Posición (x, y): (32.38 m, 16.26 m)
# Tiempo: 1.28 s - Posición (x, y): (32.63 m, 16.33 m)
# Tiempo: 1.29 s - Posición (x, y): (32.88 m, 16.39 m)
# Tiempo: 1.30 s - Posición (x, y): (33.14 m, 16.45 m)
# Tiempo: 1.31 s - Posición (x, y): (33.39 m, 16.51 m)
# Tiempo: 1.32 s - Posición (x, y): (33.64 m, 16.58 m)
# Tiempo: 1.33 s - Posición (x, y): (33.90 m, 16.64 m)
# Tiempo: 1.34 s - Posición (x, y): (34.15 m, 16.69 m)
# Tiempo: 1.35 s - Posición (x, y): (34.41 m, 16.75 m)
# Tiempo: 1.36 s - Posición (x, y): (34.66 m, 16.81 m)
# Tiempo: 1.37 s - Posición (x, y): (34.91 m, 16.87 m)
# Tiempo: 1.38 s - Posición (x, y): (35.17 m, 16.92 m)
# Tiempo: 1.39 s - Posición (x, y): (35.42 m, 16.97 m)
# Tiempo: 1.40 s - Posición (x, y): (35.67 m, 17.03 m)
# Tiempo: 1.41 s - Posición (x, y): (35.93 m, 17.08 m)
# Tiempo: 1.42 s - Posición (x, y): (36.18 m, 17.13 m)
# Tiempo: 1.43 s - Posición (x, y): (36.43 m, 17.18 m)
# Tiempo: 1.44 s - Posición (x, y): (36.69 m, 17.23 m)
# Tiempo: 1.45 s - Posición (x, y): (36.94 m, 17.28 m)
# Tiempo: 1.46 s - Posición (x, y): (37.20 m, 17.33 m)
# Tiempo: 1.47 s - Posición (x, y): (37.45 m, 17.37 m)
# Tiempo: 1.48 s - Posición (x, y): (37.70 m, 17.42 m)
# Tiempo: 1.49 s - Posición (x, y): (37.96 m, 17.46 m)
# Tiempo: 1.50 s - Posición (x, y): (38.21 m, 17.50 m)
# Tiempo: 1.51 s - Posición (x, y): (38.46 m, 17.55 m)
# Tiempo: 1.52 s - Posición (x, y): (38.72 m, 17.59 m)
# Tiempo: 1.53 s - Posición (x, y): (38.97 m, 17.63 m)
# Tiempo: 1.54 s - Posición (x, y): (39.22 m, 17.67 m)
# Tiempo: 1.55 s - Posición (x, y): (39.48 m, 17.71 m)
# Tiempo: 1.56 s - Posición (x, y): (39.73 m, 17.74 m)
# Tiempo: 1.57 s - Posición (x, y): (39.98 m, 17.78 m)
# Tiempo: 1.58 s - Posición (x, y): (40.24 m, 17.81 m)
# Tiempo: 1.59 s - Posición (x, y): (40.49 m, 17.85 m)
# Tiempo: 1.60 s - Posición (x, y): (40.74 m, 17.88 m)
# Tiempo: 1.61 s - Posición (x, y): (41.00 m, 17.92 m)
# Tiempo: 1.62 s - Posición (x, y): (41.25 m, 17.95 m)
# Tiempo: 1.63 s - Posición (x, y): (41.50 m, 17.98 m)
# Tiempo: 1.64 s - Posición (x, y): (41.76 m, 18.01 m)
# Tiempo: 1.65 s - Posición (x, y): (42.01 m, 18.04 m)
# Tiempo: 1.66 s - Posición (x, y): (42.26 m, 18.06 m)
# Tiempo: 1.67 s - Posición (x, y): (42.51 m, 18.09 m)
# Tiempo: 1.68 s - Posición (x, y): (42.77 m, 18.11 m)
# Tiempo: 1.69 s - Posición (x, y): (43.02 m, 18.14 m)
# Tiempo: 1.70 s - Posición (x, y): (43.27 m, 18.16 m)
# Tiempo: 1.71 s - Posición (x, y): (43.53 m, 18.19 m)
# Tiempo: 1.72 s - Posición (x, y): (43.78 m, 18.21 m)
# Tiempo: 1.73 s - Posición (x, y): (44.03 m, 18.23 m)
# Tiempo: 1.74 s - Posición (x, y): (44.29 m, 18.25 m)
# Tiempo: 1.75 s - Posición (x, y): (44.54 m, 18.27 m)
# Tiempo: 1.76 s - Posición (x, y): (44.79 m, 18.28 m)
# Tiempo: 1.77 s - Posición (x, y): (45.04 m, 18.30 m)
# Tiempo: 1.78 s - Posición (x, y): (45.30 m, 18.32 m)
# Tiempo: 1.79 s - Posición (x, y): (45.55 m, 18.33 m)
# Tiempo: 1.80 s - Posición (x, y): (45.80 m, 18.34 m)
# Tiempo: 1.81 s - Posición (x, y): (46.06 m, 18.36 m)
# Tiempo: 1.82 s - Posición (x, y): (46.31 m, 18.37 m)
# Tiempo: 1.83 s - Posición (x, y): (46.56 m, 18.38 m)
# Tiempo: 1.84 s - Posición (x, y): (46.81 m, 18.39 m)
# Tiempo: 1.85 s - Posición (x, y): (47.07 m, 18.40 m)
# Tiempo: 1.86 s - Posición (x, y): (47.32 m, 18.41 m)
# Tiempo: 1.87 s - Posición (x, y): (47.57 m, 18.41 m)
# Tiempo: 1.88 s - Posición (x, y): (47.83 m, 18.42 m)
# Tiempo: 1.89 s - Posición (x, y): (48.08 m, 18.42 m)
# Tiempo: 1.90 s - Posición (x, y): (48.33 m, 18.43 m)
# Tiempo: 1.91 s - Posición (x, y): (48.58 m, 18.43 m)
# Tiempo: 1.92 s - Posición (x, y): (48.84 m, 18.43 m)
# Tiempo: 1.93 s - Posición (x, y): (49.09 m, 18.43 m)
# Tiempo: 1.94 s - Posición (x, y): (49.34 m, 18.43 m)
# Tiempo: 1.95 s - Posición (x, y): (49.59 m, 18.43 m)
# Tiempo: 1.96 s - Posición (x, y): (49.85 m, 18.43 m)
# Tiempo: 1.97 s - Posición (x, y): (50.10 m, 18.43 m)
# Tiempo: 1.98 s - Posición (x, y): (50.35 m, 18.42 m)
# Tiempo: 1.99 s - Posición (x, y): (50.61 m, 18.42 m)
# Tiempo: 2.00 s - Posición (x, y): (50.86 m, 18.41 m)
# Tiempo: 2.01 s - Posición (x, y): (51.11 m, 18.41 m)
# Tiempo: 2.02 s - Posición (x, y): (51.36 m, 18.40 m)
# Tiempo: 2.03 s - Posición (x, y): (51.62 m, 18.39 m)
# Tiempo: 2.04 s - Posición (x, y): (51.87 m, 18.38 m)
# Tiempo: 2.05 s - Posición (x, y): (52.12 m, 18.37 m)
# Tiempo: 2.06 s - Posición (x, y): (52.37 m, 18.36 m)
# Tiempo: 2.07 s - Posición (x, y): (52.62 m, 18.34 m)
# Tiempo: 2.08 s - Posición (x, y): (52.88 m, 18.33 m)
# Tiempo: 2.09 s - Posición (x, y): (53.13 m, 18.31 m)
# Tiempo: 2.10 s - Posición (x, y): (53.38 m, 18.30 m)
# Tiempo: 2.11 s - Posición (x, y): (53.63 m, 18.28 m)
# Tiempo: 2.12 s - Posición (x, y): (53.89 m, 18.26 m)
# Tiempo: 2.13 s - Posición (x, y): (54.14 m, 18.25 m)
# Tiempo: 2.14 s - Posición (x, y): (54.39 m, 18.23 m)
# Tiempo: 2.15 s - Posición (x, y): (54.64 m, 18.20 m)
# Tiempo: 2.16 s - Posición (x, y): (54.90 m, 18.18 m)
# Tiempo: 2.17 s - Posición (x, y): (55.15 m, 18.16 m)
# Tiempo: 2.18 s - Posición (x, y): (55.40 m, 18.14 m)
# Tiempo: 2.19 s - Posición (x, y): (55.65 m, 18.11 m)
# Tiempo: 2.20 s - Posición (x, y): (55.90 m, 18.09 m)
# Tiempo: 2.21 s - Posición (x, y): (56.16 m, 18.06 m)
# Tiempo: 2.22 s - Posición (x, y): (56.41 m, 18.03 m)
# Tiempo: 2.23 s - Posición (x, y): (56.66 m, 18.00 m)
# Tiempo: 2.24 s - Posición (x, y): (56.91 m, 17.97 m)
# Tiempo: 2.25 s - Posición (x, y): (57.17 m, 17.94 m)
# Tiempo: 2.26 s - Posición (x, y): (57.42 m, 17.91 m)
# Tiempo: 2.27 s - Posición (x, y): (57.67 m, 17.88 m)
# Tiempo: 2.28 s - Posición (x, y): (57.92 m, 17.85 m)
# Tiempo: 2.29 s - Posición (x, y): (58.17 m, 17.81 m)
# Tiempo: 2.30 s - Posición (x, y): (58.43 m, 17.78 m)
# Tiempo: 2.31 s - Posición (x, y): (58.68 m, 17.74 m)
# Tiempo: 2.32 s - Posición (x, y): (58.93 m, 17.70 m)
# Tiempo: 2.33 s - Posición (x, y): (59.18 m, 17.66 m)
# Tiempo: 2.34 s - Posición (x, y): (59.43 m, 17.62 m)
# Tiempo: 2.35 s - Posición (x, y): (59.69 m, 17.58 m)
# Tiempo: 2.36 s - Posición (x, y): (59.94 m, 17.54 m)
# Tiempo: 2.37 s - Posición (x, y): (60.19 m, 17.50 m)
# Tiempo: 2.38 s - Posición (x, y): (60.44 m, 17.46 m)
# Tiempo: 2.39 s - Posición (x, y): (60.69 m, 17.41 m)
# Tiempo: 2.40 s - Posición (x, y): (60.95 m, 17.37 m)
# Tiempo: 2.41 s - Posición (x, y): (61.20 m, 17.32 m)
# Tiempo: 2.42 s - Posición (x, y): (61.45 m, 17.27 m)
# Tiempo: 2.43 s - Posición (x, y): (61.70 m, 17.23 m)
# Tiempo: 2.44 s - Posición (x, y): (61.95 m, 17.18 m)
# Tiempo: 2.45 s - Posición (x, y): (62.20 m, 17.13 m)
# Tiempo: 2.46 s - Posición (x, y): (62.46 m, 17.07 m)
# Tiempo: 2.47 s - Posición (x, y): (62.71 m, 17.02 m)
# Tiempo: 2.48 s - Posición (x, y): (62.96 m, 16.97 m)
# Tiempo: 2.49 s - Posición (x, y): (63.21 m, 16.92 m)
# Tiempo: 2.50 s - Posición (x, y): (63.46 m, 16.86 m)
# Tiempo: 2.51 s - Posición (x, y): (63.71 m, 16.80 m)
# Tiempo: 2.52 s - Posición (x, y): (63.97 m, 16.75 m)
# Tiempo: 2.53 s - Posición (x, y): (64.22 m, 16.69 m)
# Tiempo: 2.54 s - Posición (x, y): (64.47 m, 16.63 m)
# Tiempo: 2.55 s - Posición (x, y): (64.72 m, 16.57 m)
# Tiempo: 2.56 s - Posición (x, y): (64.97 m, 16.51 m)
# Tiempo: 2.57 s - Posición (x, y): (65.22 m, 16.45 m)
# Tiempo: 2.58 s - Posición (x, y): (65.48 m, 16.38 m)
# Tiempo: 2.59 s - Posición (x, y): (65.73 m, 16.32 m)
# Tiempo: 2.60 s - Posición (x, y): (65.98 m, 16.25 m)
# Tiempo: 2.61 s - Posición (x, y): (66.23 m, 16.19 m)
# Tiempo: 2.62 s - Posición (x, y): (66.48 m, 16.12 m)
# Tiempo: 2.63 s - Posición (x, y): (66.73 m, 16.05 m)
# Tiempo: 2.64 s - Posición (x, y): (66.98 m, 15.98 m)
# Tiempo: 2.65 s - Posición (x, y): (67.24 m, 15.91 m)
# Tiempo: 2.66 s - Posición (x, y): (67.49 m, 15.84 m)
# Tiempo: 2.67 s - Posición (x, y): (67.74 m, 15.77 m)
# Tiempo: 2.68 s - Posición (x, y): (67.99 m, 15.70 m)
# Tiempo: 2.69 s - Posición (x, y): (68.24 m, 15.63 m)
# Tiempo: 2.70 s - Posición (x, y): (68.49 m, 15.55 m)
# Tiempo: 2.71 s - Posición (x, y): (68.74 m, 15.47 m)
# Tiempo: 2.72 s - Posición (x, y): (69.00 m, 15.40 m)
# Tiempo: 2.73 s - Posición (x, y): (69.25 m, 15.32 m)
# Tiempo: 2.74 s - Posición (x, y): (69.50 m, 15.24 m)
# Tiempo: 2.75 s - Posición (x, y): (69.75 m, 15.16 m)
# Tiempo: 2.76 s - Posición (x, y): (70.00 m, 15.08 m)
# Tiempo: 2.77 s - Posición (x, y): (70.25 m, 15.00 m)
# Tiempo: 2.78 s - Posición (x, y): (70.50 m, 14.92 m)
# Tiempo: 2.79 s - Posición (x, y): (70.75 m, 14.83 m)
# Tiempo: 2.80 s - Posición (x, y): (71.01 m, 14.75 m)
# Tiempo: 2.81 s - Posición (x, y): (71.26 m, 14.66 m)
# Tiempo: 2.82 s - Posición (x, y): (71.51 m, 14.58 m)
# Tiempo: 2.83 s - Posición (x, y): (71.76 m, 14.49 m)
# Tiempo: 2.84 s - Posición (x, y): (72.01 m, 14.40 m)
# Tiempo: 2.85 s - Posición (x, y): (72.26 m, 14.31 m)
# Tiempo: 2.86 s - Posición (x, y): (72.51 m, 14.22 m)
# Tiempo: 2.87 s - Posición (x, y): (72.76 m, 14.13 m)
# Tiempo: 2.88 s - Posición (x, y): (73.01 m, 14.03 m)
# Tiempo: 2.89 s - Posición (x, y): (73.26 m, 13.94 m)
# Tiempo: 2.90 s - Posición (x, y): (73.52 m, 13.85 m)
# Tiempo: 2.91 s - Posición (x, y): (73.77 m, 13.75 m)
# Tiempo: 2.92 s - Posición (x, y): (74.02 m, 13.65 m)
# Tiempo: 2.93 s - Posición (x, y): (74.27 m, 13.56 m)
# Tiempo: 2.94 s - Posición (x, y): (74.52 m, 13.46 m)
# Tiempo: 2.95 s - Posición (x, y): (74.77 m, 13.36 m)
# Tiempo: 2.96 s - Posición (x, y): (75.02 m, 13.26 m)
# Tiempo: 2.97 s - Posición (x, y): (75.27 m, 13.16 m)
# Tiempo: 2.98 s - Posición (x, y): (75.52 m, 13.05 m)
# Tiempo: 2.99 s - Posición (x, y): (75.77 m, 12.95 m)
# Tiempo: 3.00 s - Posición (x, y): (76.02 m, 12.85 m)
# Tiempo: 3.01 s - Posición (x, y): (76.28 m, 12.74 m)
# Tiempo: 3.02 s - Posición (x, y): (76.53 m, 12.63 m)
# Tiempo: 3.03 s - Posición (x, y): (76.78 m, 12.53 m)
# Tiempo: 3.04 s - Posición (x, y): (77.03 m, 12.42 m)
# Tiempo: 3.05 s - Posición (x, y): (77.28 m, 12.31 m)
# Tiempo: 3.06 s - Posición (x, y): (77.53 m, 12.20 m)
# Tiempo: 3.07 s - Posición (x, y): (77.78 m, 12.09 m)
# Tiempo: 3.08 s - Posición (x, y): (78.03 m, 11.98 m)
# Tiempo: 3.09 s - Posición (x, y): (78.28 m, 11.86 m)
# Tiempo: 3.10 s - Posición (x, y): (78.53 m, 11.75 m)
# Tiempo: 3.11 s - Posición (x, y): (78.78 m, 11.63 m)
# Tiempo: 3.12 s - Posición (x, y): (79.03 m, 11.52 m)
# Tiempo: 3.13 s - Posición (x, y): (79.28 m, 11.40 m)
# Tiempo: 3.14 s - Posición (x, y): (79.53 m, 11.28 m)
# Tiempo: 3.15 s - Posición (x, y): (79.79 m, 11.16 m)
# Tiempo: 3.16 s - Posición (x, y): (80.04 m, 11.04 m)
# Tiempo: 3.17 s - Posición (x, y): (80.29 m, 10.92 m)
# Tiempo: 3.18 s - Posición (x, y): (80.54 m, 10.80 m)
# Tiempo: 3.19 s - Posición (x, y): (80.79 m, 10.68 m)
# Tiempo: 3.20 s - Posición (x, y): (81.04 m, 10.55 m)
# Tiempo: 3.21 s - Posición (x, y): (81.29 m, 10.43 m)
# Tiempo: 3.22 s - Posición (x, y): (81.54 m, 10.30 m)
# Tiempo: 3.23 s - Posición (x, y): (81.79 m, 10.17 m)
# Tiempo: 3.24 s - Posición (x, y): (82.04 m, 10.05 m)
# Tiempo: 3.25 s - Posición (x, y): (82.29 m, 9.92 m)
# Tiempo: 3.26 s - Posición (x, y): (82.54 m, 9.79 m)
# Tiempo: 3.27 s - Posición (x, y): (82.79 m, 9.66 m)
# Tiempo: 3.28 s - Posición (x, y): (83.04 m, 9.52 m)
# Tiempo: 3.29 s - Posición (x, y): (83.29 m, 9.39 m)
# Tiempo: 3.30 s - Posición (x, y): (83.54 m, 9.26 m)
# Tiempo: 3.31 s - Posición (x, y): (83.79 m, 9.12 m)
# Tiempo: 3.32 s - Posición (x, y): (84.04 m, 8.99 m)
# Tiempo: 3.33 s - Posición (x, y): (84.29 m, 8.85 m)
# Tiempo: 3.34 s - Posición (x, y): (84.54 m, 8.71 m)
# Tiempo: 3.35 s - Posición (x, y): (84.79 m, 8.57 m)
# Tiempo: 3.36 s - Posición (x, y): (85.04 m, 8.43 m)
# Tiempo: 3.37 s - Posición (x, y): (85.29 m, 8.29 m)
# Tiempo: 3.38 s - Posición (x, y): (85.54 m, 8.15 m)
# Tiempo: 3.39 s - Posición (x, y): (85.79 m, 8.01 m)
# Tiempo: 3.40 s - Posición (x, y): (86.04 m, 7.86 m)
# Tiempo: 3.41 s - Posición (x, y): (86.29 m, 7.72 m)
# Tiempo: 3.42 s - Posición (x, y): (86.54 m, 7.57 m)
# Tiempo: 3.43 s - Posición (x, y): (86.79 m, 7.43 m)
# Tiempo: 3.44 s - Posición (x, y): (87.04 m, 7.28 m)
# Tiempo: 3.45 s - Posición (x, y): (87.29 m, 7.13 m)
# Tiempo: 3.46 s - Posición (x, y): (87.54 m, 6.98 m)
# Tiempo: 3.47 s - Posición (x, y): (87.79 m, 6.83 m)
# Tiempo: 3.48 s - Posición (x, y): (88.04 m, 6.68 m)
# Tiempo: 3.49 s - Posición (x, y): (88.29 m, 6.52 m)
# Tiempo: 3.50 s - Posición (x, y): (88.54 m, 6.37 m)
# Tiempo: 3.51 s - Posición (x, y): (88.79 m, 6.22 m)
# Tiempo: 3.52 s - Posición (x, y): (89.04 m, 6.06 m)
# Tiempo: 3.53 s - Posición (x, y): (89.29 m, 5.90 m)
# Tiempo: 3.54 s - Posición (x, y): (89.54 m, 5.75 m)
# Tiempo: 3.55 s - Posición (x, y): (89.79 m, 5.59 m)
# Tiempo: 3.56 s - Posición (x, y): (90.04 m, 5.43 m)
# Tiempo: 3.57 s - Posición (x, y): (90.29 m, 5.27 m)
# Tiempo: 3.58 s - Posición (x, y): (90.54 m, 5.11 m)
# Tiempo: 3.59 s - Posición (x, y): (90.79 m, 4.94 m)
# Tiempo: 3.60 s - Posición (x, y): (91.04 m, 4.78 m)
# Tiempo: 3.61 s - Posición (x, y): (91.29 m, 4.62 m)
# Tiempo: 3.62 s - Posición (x, y): (91.54 m, 4.45 m)
# Tiempo: 3.63 s - Posición (x, y): (91.79 m, 4.28 m)
# Tiempo: 3.64 s - Posición (x, y): (92.04 m, 4.12 m)
# Tiempo: 3.65 s - Posición (x, y): (92.29 m, 3.95 m)
# Tiempo: 3.66 s - Posición (x, y): (92.54 m, 3.78 m)
# Tiempo: 3.67 s - Posición (x, y): (92.79 m, 3.61 m)
# Tiempo: 3.68 s - Posición (x, y): (93.04 m, 3.44 m)
# Tiempo: 3.69 s - Posición (x, y): (93.29 m, 3.26 m)
# Tiempo: 3.70 s - Posición (x, y): (93.54 m, 3.09 m)
# Tiempo: 3.71 s - Posición (x, y): (93.79 m, 2.92 m)
# Tiempo: 3.72 s - Posición (x, y): (94.04 m, 2.74 m)
# Tiempo: 3.73 s - Posición (x, y): (94.29 m, 2.57 m)
# Tiempo: 3.74 s - Posición (x, y): (94.54 m, 2.39 m)
# Tiempo: 3.75 s - Posición (x, y): (94.79 m, 2.21 m)
# Tiempo: 3.76 s - Posición (x, y): (95.04 m, 2.03 m)
# Tiempo: 3.77 s - Posición (x, y): (95.29 m, 1.85 m)
# Tiempo: 3.78 s - Posición (x, y): (95.54 m, 1.67 m)
# Tiempo: 3.79 s - Posición (x, y): (95.79 m, 1.49 m)
# Tiempo: 3.80 s - Posición (x, y): (96.03 m, 1.30 m)
# Tiempo: 3.81 s - Posición (x, y): (96.28 m, 1.12 m)
# Tiempo: 3.82 s - Posición (x, y): (96.53 m, 0.94 m)
# Tiempo: 3.83 s - Posición (x, y): (96.78 m, 0.75 m)
# Tiempo: 3.84 s - Posición (x, y): (97.03 m, 0.56 m)
# Tiempo: 3.85 s - Posición (x, y): (97.28 m, 0.37 m)
# Tiempo: 3.86 s - Posición (x, y): (97.53 m, 0.19 m)
# Tiempo: 3.87 s - Posición (x, y): (97.78 m, -0.00 m)
